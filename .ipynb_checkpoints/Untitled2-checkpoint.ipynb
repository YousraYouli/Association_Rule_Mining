# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.23.3-py3-none-any.whl.metadata (7.3 kB)
# Collecting scipy>=1.2.1 (from mlxtend)
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting numpy>=1.16.2 (from mlxtend)
#   Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pandas>=0.24.2 (from mlxtend)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn>=1.3.1 (from mlxtend)
#   Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting matplotlib>=3.0.0 (from mlxtend)
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting joblib>=0.13.2 (from mlxtend)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0.0->mlxtend)
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0.0->mlxtend)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0.0->mlxtend)
#   Using cached fonttools-4.55.0-cp312-cp312-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0.0->mlxtend)
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\soso\desktop\association\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Collecting pillow>=8 (from matplotlib>=3.0.0->mlxtend)
#   Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.0.0->mlxtend)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\soso\desktop\association\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=0.24.2->mlxtend)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.24.2->mlxtend)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.1->mlxtend)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\soso\desktop\association\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Using cached mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.55.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, mlxtend
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.0 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.2 mlxtend-0.23.3 numpy-2.1.3 pandas-2.2.3 pillow-11.0.0 pyparsing-3.2.0 pytz-2024.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0 tzdata-2024.2

# %%
dataframe= pd.read_csv("data/Groceries_dataset.csv")
dataframe
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# 2. Prétraitement: Grouper les articles par chaque transaction
transactions = dataframe.groupby('Member_number')['itemDescription'].apply(list)
transactions
# Out:
# Member_number
# 1000    [soda, canned beer, sausage, sausage, whole mi...
# 1001    [frankfurter, frankfurter, beef, sausage, whol...
# 1002    [tropical fruit, butter milk, butter, frozen v...
# 1003    [sausage, root vegetables, rolls/buns, deterge...
# 1004    [other vegetables, pip fruit, root vegetables,...
#                               ...
# 4996    [dessert, salty snack, rolls/buns, misc. bever...
# 4997    [tropical fruit, white wine, whole milk, curd,...
# 4998                                   [rolls/buns, curd]
# 4999    [bottled water, butter milk, tropical fruit, b...
# 5000    [soda, bottled beer, fruit/vegetable juice, ro...
# Name: itemDescription, Length: 3898, dtype: object

# %%
# 3. Convertir les transactions au format One-Hot Encoding
encoder = TransactionEncoder()
pred = encoder.fit_transform(transactions)
df = pd.DataFrame(pred,columns = encoder.columns_)
df
# Out:
#       Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                     False     False             False             False
# 1                     False     False             False             False
# 2                     False     False             False             False
# 3                     False     False             False             False
# 4                     False     False             False             False
# ...                     ...       ...               ...               ...
# 3893                  False     False             False             False
# 3894                  False     False             False             False
# 3895                  False     False             False             False
# 3896                  False     False             False             False
# 3897                  False     False             False             False
#
#       baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0              False  False          False             False  False    False
# 1              False  False          False             False   True    False
# 2              False  False          False             False  False    False
# 3              False  False          False             False  False    False
# 4              False  False          False             False  False    False
# ...              ...    ...            ...               ...    ...      ...
# 3893           False  False          False             False  False    False
# 3894           False  False          False             False  False    False
# 3895           False  False          False             False  False    False
# 3896           False  False          False             False  False     True
# 3897           False  False          False             False  False    False
#
#       ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0     ...   False    False    False               False   False        False
# 1     ...   False    False    False                True   False         True
# 2     ...   False    False    False               False   False        False
# 3     ...   False    False    False               False   False        False
# 4     ...   False    False    False               False   False        False
# ...   ...     ...      ...      ...                 ...     ...          ...
# 3893  ...   False    False    False               False   False        False
# 3894  ...   False    False    False               False   False        False
# 3895  ...   False    False    False               False   False        False
# 3896  ...   False    False    False                True   False        False
# 3897  ...   False    False    False               False   False        False
#
#       white wine  whole milk  yogurt  zwieback
# 0          False        True    True     False
# 1          False        True   False     False
# 2          False        True   False     False
# 3          False       False   False     False
# 4          False        True   False     False
# ...          ...         ...     ...       ...
# 3893       False       False   False     False
# 3894        True        True   False     False
# 3895       False       False   False     False
# 3896       False       False    True     False
# 3897       False       False   False     False
#
# [3898 rows x 167 columns]

# %%
# Find frequent itemsets : support
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
print("frequent_itemsets :" )
frequent_itemsets
# Out:
# frequent_itemsets :
#       support                                           itemsets
# 0    0.333333                                            (Apple)
# 1    0.333333                                             (Corn)
# 2    0.166667                                             (Dill)
# 3    0.666667                                             (Eggs)
# 4    0.333333                                        (Ice cream)
# ..        ...                                                ...
# 149  0.333333        (Yogurt, Nutmeg, Onion, Eggs, Kidney Beans)
# 150  0.166667                (Milk, Yogurt, Nutmeg, Onion, Eggs)
# 151  0.166667        (Milk, Yogurt, Nutmeg, Onion, Kidney Beans)
# 152  0.166667  (Yogurt, Dill, Nutmeg, Onion, Eggs, Kidney Beans)
# 153  0.166667  (Milk, Yogurt, Nutmeg, Onion, Eggs, Kidney Beans)
#
# [154 rows x 2 columns]

# %%
# Generate association rules
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1 ,num_itemsets=2)
# rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=1 ,num_itemsets=2)
#.head(50)
rules
# Out:
#          antecedents                                  consequents  \
# 0            (Apple)                                       (Eggs)
# 1             (Eggs)                                      (Apple)
# 2            (Apple)                                  (Ice cream)
# 3        (Ice cream)                                      (Apple)
# 4             (Milk)                                      (Apple)
# ...              ...                                          ...
# 1307        (Yogurt)    (Milk, Nutmeg, Onion, Eggs, Kidney Beans)
# 1308        (Nutmeg)    (Milk, Yogurt, Onion, Eggs, Kidney Beans)
# 1309         (Onion)   (Milk, Yogurt, Nutmeg, Eggs, Kidney Beans)
# 1310          (Eggs)  (Milk, Yogurt, Nutmeg, Onion, Kidney Beans)
# 1311  (Kidney Beans)          (Milk, Yogurt, Nutmeg, Onion, Eggs)
#
#       antecedent support  consequent support   support  confidence  lift  \
# 0               0.333333            0.666667  0.333333    1.000000   1.5
# 1               0.666667            0.333333  0.333333    0.500000   1.5
# 2               0.333333            0.333333  0.166667    0.500000   1.5
# 3               0.333333            0.333333  0.166667    0.500000   1.5
# 4               0.666667            0.333333  0.333333    0.500000   1.5
# ...                  ...                 ...       ...         ...   ...
# 1307            0.666667            0.166667  0.166667    0.250000   1.5
# 1308            0.333333            0.166667  0.166667    0.500000   3.0
# 1309            0.500000            0.166667  0.166667    0.333333   2.0
# 1310            0.666667            0.166667  0.166667    0.250000   1.5
# 1311            0.833333            0.166667  0.166667    0.200000   1.2
#
#       representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                  1.0  0.111111         inf            0.5  0.500000
# 1                  1.0  0.111111    1.333333            1.0  0.500000
# 2                  1.0  0.055556    1.333333            0.5  0.333333
# 3                  1.0  0.055556    1.333333            0.5  0.333333
# 4                  1.0  0.111111    1.333333            1.0  0.500000
# ...                ...       ...         ...            ...       ...
# 1307               1.0  0.055556    1.111111            1.0  0.250000
# 1308               1.0  0.111111    1.666667            1.0  0.500000
# 1309               1.0  0.083333    1.250000            1.0  0.333333
# 1310               1.0  0.055556    1.111111            1.0  0.250000
# 1311               1.0  0.027778    1.041667            1.0  0.200000
#
#       certainty  kulczynski
# 0          1.00    0.750000
# 1          0.25    0.750000
# 2          0.25    0.500000
# 3          0.25    0.500000
# 4          0.25    0.750000
# ...         ...         ...
# 1307       0.10    0.625000
# 1308       0.40    0.750000
# 1309       0.20    0.666667
# 1310       0.10    0.625000
# 1311       0.04    0.600000
#
# [1312 rows x 14 columns]

# %%
# Afficher des statistiques supplémentaires sur les règles générées
print("### Statistiques sur les Règles d'Association")
print(f"Nombre total de règles générées: {len(rules)}")
print(f"Règles avec un lift supérieur à 1 (indiquant des associations intéressantes):")
rules[rules['lift'] > 1].head(50)
# Out:
# ### Statistiques sur les Règles d'Association
# Nombre total de règles générées: 1312
# Règles avec un lift supérieur à 1 (indiquant des associations intéressantes):
#            antecedents        consequents  antecedent support  \
# 0              (Apple)             (Eggs)            0.333333
# 1               (Eggs)            (Apple)            0.666667
# 2              (Apple)        (Ice cream)            0.333333
# 3          (Ice cream)            (Apple)            0.333333
# 4               (Milk)            (Apple)            0.666667
# 5              (Apple)             (Milk)            0.333333
# 6               (Corn)        (Ice cream)            0.333333
# 7          (Ice cream)             (Corn)            0.333333
# 8       (Kidney Beans)             (Corn)            0.833333
# 9               (Corn)     (Kidney Beans)            0.333333
# 12           (Unicorn)             (Corn)            0.166667
# 13              (Corn)          (Unicorn)            0.333333
# 14            (Yogurt)             (Corn)            0.666667
# 15              (Corn)           (Yogurt)            0.333333
# 16              (Eggs)             (Dill)            0.666667
# 17              (Dill)             (Eggs)            0.166667
# 18      (Kidney Beans)             (Dill)            0.833333
# 19              (Dill)     (Kidney Beans)            0.166667
# 20              (Dill)           (Nutmeg)            0.166667
# 21            (Nutmeg)             (Dill)            0.333333
# 22             (Onion)             (Dill)            0.500000
# 23              (Dill)            (Onion)            0.166667
# 24            (Yogurt)             (Dill)            0.666667
# 25              (Dill)           (Yogurt)            0.166667
# 26              (Milk)             (Eggs)            0.666667
# 27              (Eggs)             (Milk)            0.666667
# 28              (Eggs)           (Nutmeg)            0.666667
# 29            (Nutmeg)             (Eggs)            0.333333
# 34      (Kidney Beans)           (Nutmeg)            0.833333
# 35            (Nutmeg)     (Kidney Beans)            0.333333
# 36             (Onion)     (Kidney Beans)            0.500000
# 37      (Kidney Beans)            (Onion)            0.833333
# 38           (Unicorn)     (Kidney Beans)            0.166667
# 39      (Kidney Beans)          (Unicorn)            0.833333
# 40      (Kidney Beans)           (Yogurt)            0.833333
# 41            (Yogurt)     (Kidney Beans)            0.666667
# 42           (Unicorn)             (Milk)            0.166667
# 43              (Milk)          (Unicorn)            0.666667
# 44             (Onion)           (Nutmeg)            0.500000
# 45            (Nutmeg)            (Onion)            0.333333
# 46            (Yogurt)           (Nutmeg)            0.666667
# 47            (Nutmeg)           (Yogurt)            0.333333
# 48             (Onion)           (Yogurt)            0.500000
# 49            (Yogurt)            (Onion)            0.666667
# 50           (Unicorn)           (Yogurt)            0.166667
# 51            (Yogurt)          (Unicorn)            0.666667
# 52       (Apple, Eggs)        (Ice cream)            0.333333
# 53  (Apple, Ice cream)             (Eggs)            0.166667
# 54   (Eggs, Ice cream)            (Apple)            0.166667
# 55             (Apple)  (Eggs, Ice cream)            0.333333
#
#     consequent support   support  confidence   lift  representativity  \
# 0             0.666667  0.333333    1.000000  1.500               1.0
# 1             0.333333  0.333333    0.500000  1.500               1.0
# 2             0.333333  0.166667    0.500000  1.500               1.0
# 3             0.333333  0.166667    0.500000  1.500               1.0
# 4             0.333333  0.333333    0.500000  1.500               1.0
# 5             0.666667  0.333333    1.000000  1.500               1.0
# 6             0.333333  0.166667    0.500000  1.500               1.0
# 7             0.333333  0.166667    0.500000  1.500               1.0
# 8             0.333333  0.333333    0.400000  1.200               1.0
# 9             0.833333  0.333333    1.000000  1.200               1.0
# 12            0.333333  0.166667    1.000000  3.000               1.0
# 13            0.166667  0.166667    0.500000  3.000               1.0
# 14            0.333333  0.333333    0.500000  1.500               1.0
# 15            0.666667  0.333333    1.000000  1.500               1.0
# 16            0.166667  0.166667    0.250000  1.500               1.0
# 17            0.666667  0.166667    1.000000  1.500               1.0
# 18            0.166667  0.166667    0.200000  1.200               1.0
# 19            0.833333  0.166667    1.000000  1.200               1.0
# 20            0.333333  0.166667    1.000000  3.000               1.0
# 21            0.166667  0.166667    0.500000  3.000               1.0
# 22            0.166667  0.166667    0.333333  2.000               1.0
# 23            0.500000  0.166667    1.000000  2.000               1.0
# 24            0.166667  0.166667    0.250000  1.500               1.0
# 25            0.666667  0.166667    1.000000  1.500               1.0
# 26            0.666667  0.500000    0.750000  1.125               1.0
# 27            0.666667  0.500000    0.750000  1.125               1.0
# 28            0.333333  0.333333    0.500000  1.500               1.0
# 29            0.666667  0.333333    1.000000  1.500               1.0
# 34            0.333333  0.333333    0.400000  1.200               1.0
# 35            0.833333  0.333333    1.000000  1.200               1.0
# 36            0.833333  0.500000    1.000000  1.200               1.0
# 37            0.500000  0.500000    0.600000  1.200               1.0
# 38            0.833333  0.166667    1.000000  1.200               1.0
# 39            0.166667  0.166667    0.200000  1.200               1.0
# 40            0.666667  0.666667    0.800000  1.200               1.0
# 41            0.833333  0.666667    1.000000  1.200               1.0
# 42            0.666667  0.166667    1.000000  1.500               1.0
# 43            0.166667  0.166667    0.250000  1.500               1.0
# 44            0.333333  0.333333    0.666667  2.000               1.0
# 45            0.500000  0.333333    1.000000  2.000               1.0
# 46            0.333333  0.333333    0.500000  1.500               1.0
# 47            0.666667  0.333333    1.000000  1.500               1.0
# 48            0.666667  0.500000    1.000000  1.500               1.0
# 49            0.500000  0.500000    0.750000  1.500               1.0
# 50            0.666667  0.166667    1.000000  1.500               1.0
# 51            0.166667  0.166667    0.250000  1.500               1.0
# 52            0.333333  0.166667    0.500000  1.500               1.0
# 53            0.666667  0.166667    1.000000  1.500               1.0
# 54            0.333333  0.166667    1.000000  3.000               1.0
# 55            0.166667  0.166667    0.500000  3.000               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.111111         inf       0.500000  0.500000       1.00    0.750000
# 1   0.111111    1.333333       1.000000  0.500000       0.25    0.750000
# 2   0.055556    1.333333       0.500000  0.333333       0.25    0.500000
# 3   0.055556    1.333333       0.500000  0.333333       0.25    0.500000
# 4   0.111111    1.333333       1.000000  0.500000       0.25    0.750000
# 5   0.111111         inf       0.500000  0.500000       1.00    0.750000
# 6   0.055556    1.333333       0.500000  0.333333       0.25    0.500000
# 7   0.055556    1.333333       0.500000  0.333333       0.25    0.500000
# 8   0.055556    1.111111       1.000000  0.400000       0.10    0.700000
# 9   0.055556         inf       0.250000  0.400000       1.00    0.700000
# 12  0.111111         inf       0.800000  0.500000       1.00    0.750000
# 13  0.111111    1.666667       1.000000  0.500000       0.40    0.750000
# 14  0.111111    1.333333       1.000000  0.500000       0.25    0.750000
# 15  0.111111         inf       0.500000  0.500000       1.00    0.750000
# 16  0.055556    1.111111       1.000000  0.250000       0.10    0.625000
# 17  0.055556         inf       0.400000  0.250000       1.00    0.625000
# 18  0.027778    1.041667       1.000000  0.200000       0.04    0.600000
# 19  0.027778         inf       0.200000  0.200000       1.00    0.600000
# 20  0.111111         inf       0.800000  0.500000       1.00    0.750000
# 21  0.111111    1.666667       1.000000  0.500000       0.40    0.750000
# 22  0.083333    1.250000       1.000000  0.333333       0.20    0.666667
# 23  0.083333         inf       0.600000  0.333333       1.00    0.666667
# 24  0.055556    1.111111       1.000000  0.250000       0.10    0.625000
# 25  0.055556         inf       0.400000  0.250000       1.00    0.625000
# 26  0.055556    1.333333       0.333333  0.600000       0.25    0.750000
# 27  0.055556    1.333333       0.333333  0.600000       0.25    0.750000
# 28  0.111111    1.333333       1.000000  0.500000       0.25    0.750000
# 29  0.111111         inf       0.500000  0.500000       1.00    0.750000
# 34  0.055556    1.111111       1.000000  0.400000       0.10    0.700000
# 35  0.055556         inf       0.250000  0.400000       1.00    0.700000
# 36  0.083333         inf       0.333333  0.600000       1.00    0.800000
# 37  0.083333    1.250000       1.000000  0.600000       0.20    0.800000
# 38  0.027778         inf       0.200000  0.200000       1.00    0.600000
# 39  0.027778    1.041667       1.000000  0.200000       0.04    0.600000
# 40  0.111111    1.666667       1.000000  0.800000       0.40    0.900000
# 41  0.111111         inf       0.500000  0.800000       1.00    0.900000
# 42  0.055556         inf       0.400000  0.250000       1.00    0.625000
# 43  0.055556    1.111111       1.000000  0.250000       0.10    0.625000
# 44  0.166667    2.000000       1.000000  0.666667       0.50    0.833333
# 45  0.166667         inf       0.750000  0.666667       1.00    0.833333
# 46  0.111111    1.333333       1.000000  0.500000       0.25    0.750000
# 47  0.111111         inf       0.500000  0.500000       1.00    0.750000
# 48  0.166667         inf       0.666667  0.750000       1.00    0.875000
# 49  0.166667    2.000000       1.000000  0.750000       0.50    0.875000
# 50  0.055556         inf       0.400000  0.250000       1.00    0.625000
# 51  0.055556    1.111111       1.000000  0.250000       0.10    0.625000
# 52  0.055556    1.333333       0.500000  0.333333       0.25    0.500000
# 53  0.055556         inf       0.400000  0.250000       1.00    0.625000
# 54  0.111111         inf       0.800000  0.500000       1.00    0.750000
# 55  0.111111    1.666667       1.000000  0.500000       0.40    0.750000

# %%
def predict(new_transaction):
    recommendations = set()  # Use a set to eliminate duplicates
    for index, row in rules.iterrows():
        antecedents = row['antecedents']
        consequents = row['consequents']
        if all(item in new_transaction for item in antecedents):
            recommendations.add(tuple(consequents))  # Add tuples to the set
    return list(recommendations)
new_transaction = ['Milk', 'Yogurt']
recommendations = predict(new_transaction)
recommendations
# Out:
# [('Milk', 'Kidney Beans'),
#  ('Kidney Beans', 'Corn', 'Ice cream'),
#  ('Nutmeg',),
#  ('Eggs', 'Kidney Beans', 'Nutmeg'),
#  ('Onion', 'Eggs'),
#  ('Kidney Beans', 'Onion', 'Dill', 'Nutmeg'),
#  ('Apple', 'Eggs'),
#  ('Milk', 'Unicorn', 'Corn'),
#  ('Onion', 'Nutmeg'),
#  ('Milk', 'Eggs', 'Onion', 'Nutmeg'),
#  ('Kidney Beans', 'Ice cream'),
#  ('Unicorn', 'Yogurt', 'Corn'),
#  ('Onion', 'Kidney Beans', 'Ice cream'),
#  ('Milk', 'Onion', 'Kidney Beans'),
#  ('Dill', 'Nutmeg'),
#  ('Eggs', 'Ice cream'),
#  ('Onion', 'Dill', 'Nutmeg'),
#  ('Milk', 'Eggs', 'Kidney Beans', 'Nutmeg'),
#  ('Kidney Beans', 'Dill'),
#  ('Milk', 'Nutmeg', 'Onion', 'Eggs', 'Kidney Beans'),
#  ('Onion', 'Kidney Beans', 'Dill'),
#  ('Apple', 'Eggs', 'Kidney Beans'),
#  ('Onion', 'Corn'),
#  ('Eggs', 'Kidney Beans'),
#  ('Onion', 'Eggs', 'Kidney Beans'),
#  ('Eggs', 'Dill'),
#  ('Onion', 'Corn', 'Kidney Beans', 'Ice cream'),
#  ('Milk', 'Onion'),
#  ('Onion', 'Eggs', 'Dill'),
#  ('Milk', 'Nutmeg'),
#  ('Unicorn', 'Kidney Beans'),
#  ('Onion', 'Kidney Beans', 'Corn'),
#  ('Unicorn', 'Milk', 'Kidney Beans'),
#  ('Kidney Beans',),
#  ('Apple', 'Eggs', 'Ice cream'),
#  ('Milk', 'Corn'),
#  ('Kidney Beans', 'Dill', 'Nutmeg'),
#  ('Milk', 'Onion', 'Eggs'),
#  ('Dill',),
#  ('Apple',),
#  ('Dill', 'Nutmeg', 'Onion', 'Eggs', 'Kidney Beans'),
#  ('Kidney Beans', 'Nutmeg'),
#  ('Onion', 'Kidney Beans', 'Nutmeg'),
#  ('Milk', 'Eggs', 'Onion', 'Kidney Beans'),
#  ('Eggs', 'Nutmeg'),
#  ('Kidney Beans', 'Eggs', 'Dill', 'Nutmeg'),
#  ('Onion', 'Eggs', 'Nutmeg'),
#  ('Eggs', 'Onion', 'Kidney Beans', 'Nutmeg'),
#  ('Eggs', 'Onion', 'Kidney Beans'),
#  ('Kidney Beans', 'Corn'),
#  ('Unicorn', 'Kidney Beans', 'Yogurt'),
#  ('Eggs',),
#  ('Eggs', 'Dill', 'Nutmeg'),
#  ('Unicorn', 'Yogurt'),
#  ('Eggs', 'Kidney Beans', 'Dill'),
#  ('Onion', 'Ice cream'),
#  ('Unicorn', 'Kidney Beans', 'Corn'),
#  ('Apple', 'Ice cream'),
#  ('Corn', 'Ice cream'),
#  ('Onion', 'Corn', 'Ice cream'),
#  ('Milk', 'Onion', 'Nutmeg'),
#  ('Unicorn', 'Corn'),
#  ('Onion', 'Kidney Beans'),
#  ('Onion', 'Dill'),
#  ('Apple', 'Kidney Beans'),
#  ('Milk', 'Kidney Beans', 'Nutmeg'),
#  ('Unicorn', 'Milk'),
#  ('Corn',),
#  ('Milk', 'Eggs', 'Nutmeg'),
#  ('Unicorn', 'Kidney Beans', 'Yogurt', 'Corn'),
#  ('Milk', 'Kidney Beans', 'Unicorn', 'Corn'),
#  ('Milk', 'Onion', 'Kidney Beans', 'Nutmeg'),
#  ('Unicorn',),
#  ('Eggs', 'Onion', 'Nutmeg'),
#  ('Milk', 'Kidney Beans', 'Corn'),
#  ('Onion',),
#  ('Kidney Beans', 'Eggs', 'Onion', 'Dill'),
#  ('Eggs', 'Onion', 'Dill', 'Nutmeg')]
